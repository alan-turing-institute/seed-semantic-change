# %%
# Basic variables and imports:

import codecs, csv, os, time, re, io
from os import listdir
from os.path import isfile, join
from  more_itertools import unique_everseen
from collections import Counter

# directories

# change dir_in for where the new outputs are
dir_in = os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), "src", "dynamic-senses","greek_input","all_results","genre_topic_output"))
dir_out = os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), "src", "dynamic-senses","greek_input","all_results","genre_topic_output","unique_versions"))

# %%
output_file = io.open(dir_in+"/example_3genre_output.dat","r") # change this to whatever it's called
output_file_bis = io.open(dir_in+"/example_3genre_output.dat","r") # change this to whatever it's called


output_id = os.path.basename(output_file.name)
for line in output_file_bis.readlines()[1:2]:
    deuxieme_ligne_split = line.split(",")
    print(deuxieme_ligne_split)
    k = deuxieme_ligne_split[4]
    k = k.replace(" ","")
    k = k.replace("K","")
    k = int(k)
    print("k",k)

output_file = output_file.read()
output_files = list() # here we store filenames for the deduplicated

compteur = 0
liste_times = list()

splitted = output_file.split("===============  per time  ===============")[1].split("\n")
first_splitted = output_file.split("===============  per time  ===============")[0].split("\n")

for i in range(0,len(splitted)):
    if splitted[i][0:5] == "Time=": # for every line starting with "Time=" we count
        compteur+=1
        ok_time = splitted[i][0:8].replace(" ","")
        liste_times.append(ok_time) # we append this thing
        
print(liste_times)

final_number_of_output_files = 0
number_of_output_files = Counter(liste_times)

for key in number_of_output_files.keys():
    final_number_of_output_files = number_of_output_files[key]
    
print(final_number_of_output_files)

final_files = dict()
for numero in range(1,final_number_of_output_files+1):
    
    final_files[numero] = io.open(dir_out+"/"+output_id+"_"+str(numero),"w")
# Out:
# ['kappaF 10.000000', ' kappaK 4.000000', ' a0 7.000000', ' b0 3.000000', ' K 5', ' max_docs_per_slice 2000', ' start -430', ' end 364', ' times 7', ' dT 100', ' I 100\n']
# k 5
# ['Time=0', 'Time=0', 'Time=0', 'Time=1', 'Time=1', 'Time=1', 'Time=2', 'Time=2', 'Time=2', 'Time=3', 'Time=3', 'Time=3', 'Time=4', 'Time=4', 'Time=4', 'Time=5', 'Time=5', 'Time=5', 'Time=6', 'Time=6', 'Time=6']
# 3

# %%
already_seen_first = dict()

for line in first_splitted:
    if line[:6] == "p(w|s)":
        check_this = line.split(":")[0]
        check_this = check_this.split("  ")[1]
        print(check_this)
        if check_this in already_seen_first.keys():
            final_files[already_seen_first[check_this]+1].write("\n")
            final_files[already_seen_first[check_this]+1].write(line)
            final_files[already_seen_first[check_this]+1].write("\n")
            print(final_files[already_seen_first[check_this]+1])
            already_seen_first[check_this] += 1
            
        else:
            already_seen_first[check_this] = 0
            final_files[already_seen_first[check_this]+1].write("\n")
            final_files[already_seen_first[check_this]+1].write(line)
            final_files[already_seen_first[check_this]+1].write("\n")
            print(final_files[already_seen_first[check_this]+1])
            already_seen_first[check_this] += 1
# Out:
# T=-1,K=0
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# T=-1,K=1
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# T=-1,K=2
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# T=-1,K=3
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# T=-1,K=4
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# T=-1,K=0
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# T=-1,K=1
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# T=-1,K=2
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# T=-1,K=3
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# T=-1,K=4
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# T=-1,K=0
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# T=-1,K=1
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# T=-1,K=2
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# T=-1,K=3
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# T=-1,K=4
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>

# %%
for key in final_files.keys():
    final_files[key].write("\n\n\n")
    final_files[key].write("===============  per time  ===============")
    final_files[key].write("\n\n\n")

# %%
already_seen = dict()

for i in range(0,len(splitted)):
    if splitted[i][0:5] == "Time=": # for every line starting with "Time=" we count
        ok_time = splitted[i][0:8].replace(" ","")
        
        if ok_time in already_seen.keys():
            final_files[already_seen[ok_time]+1].write("\n")
            final_files[already_seen[ok_time]+1].write(ok_time)
            final_files[already_seen[ok_time]+1].write("\n")
            
            for ligne in range(i+1,i+k+1): # for k lines after i
                final_files[already_seen[ok_time]+1].write(splitted[ligne])
                final_files[already_seen[ok_time]+1].write("\n")
                print(final_files[already_seen[ok_time]+1])

                
            already_seen[ok_time] += 1
            
        else:
            already_seen[ok_time] = 0
            final_files[already_seen[ok_time]+1].write("\n")
            final_files[already_seen[ok_time]+1].write(ok_time)
            final_files[already_seen[ok_time]+1].write("\n")
            for ligne in range(i+1,i+k+1): # for k lines after i
                print(ligne)
                print(splitted[ligne])
                print(final_files[already_seen[ok_time]+1])
                final_files[already_seen[ok_time]+1].write(splitted[ligne])
                final_files[already_seen[ok_time]+1].write("\n")
            already_seen[ok_time] = 1
                
            #already_seen[ok_time] += 0
# Out:
# 2
# 0.01790193328287157   T=0,K=0:  33969 (0.056) ; 15609 (0.056) ; 71404 (0.045) ; 35417 (0.044) ; 22425 (0.038) ; 106502 (0.032) ; 48436 (0.032) ; 64316 (0.029) ; 104421 (0.027) ; 83174 (0.024) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 3
# 0.049410539070879854   T=0,K=1:  73221 (0.168) ; 13317 (0.071) ; 114753 (0.046) ; 47735 (0.041) ; 46216 (0.038) ; 61245 (0.030) ; 102514 (0.029) ; 2224 (0.028) ; nlsj42558 (0.028) ; 94677 (0.023) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 4
# 0.4525322552187352   T=0,K=2:  86219 (0.084) ; 28002 (0.063) ; 114816 (0.056) ; 59501 (0.052) ; 31236 (0.040) ; 113560 (0.036) ; 97252 (0.033) ; 106676 (0.028) ; 80761 (0.028) ; 108652 (0.026) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 5
# 0.2280886157955382   T=0,K=3:  111764 (0.073) ; 34522 (0.063) ; 60646 (0.054) ; 57466 (0.053) ; 72268 (0.044) ; 94365 (0.036) ; 24436 (0.030) ; 114816 (0.029) ; 3630 (0.028) ; 112472 (0.028) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 6
# 0.2520666566319751   T=0,K=4:  51661 (0.051) ; 22209 (0.050) ; 110598 (0.048) ; nlsj80958 (0.039) ; 35244 (0.036) ; 22100 (0.034) ; 56810 (0.034) ; 75954 (0.031) ; 31562 (0.028) ; 15609 (0.025) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# 23
# 0.02074156175695227   T=1,K=0:  33969 (0.079) ; 15609 (0.051) ; 64316 (0.041) ; 71404 (0.038) ; 48436 (0.037) ; 22425 (0.037) ; nlsj96033 (0.037) ; 106502 (0.037) ; 35417 (0.032) ; 7793 (0.025) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 24
# 0.13552160644809763   T=1,K=1:  73221 (0.161) ; 13317 (0.090) ; 114753 (0.043) ; 75948 (0.034) ; 61245 (0.033) ; 46216 (0.032) ; 68335 (0.031) ; 2224 (0.029) ; 94677 (0.028) ; 102514 (0.025) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 25
# 0.40048615120071424   T=1,K=2:  28002 (0.057) ; 113560 (0.045) ; 59501 (0.040) ; 86219 (0.039) ; 31236 (0.035) ; 22100 (0.033) ; 114816 (0.032) ; 106676 (0.030) ; 108652 (0.028) ; 93417 (0.026) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 26
# 0.19313989323610437   T=1,K=3:  57466 (0.068) ; 111764 (0.060) ; 72268 (0.049) ; 34522 (0.048) ; 15609 (0.043) ; 94365 (0.042) ; 46216 (0.041) ; 60646 (0.039) ; 24436 (0.035) ; 112472 (0.032) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 27
# 0.25011078735813147   T=1,K=4:  22209 (0.083) ; 110598 (0.061) ; 56810 (0.043) ; nlsj80958 (0.042) ; 22100 (0.036) ; 86108 (0.036) ; 31562 (0.033) ; 51661 (0.031) ; 35244 (0.024) ; 26684 (0.024) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# 44
# 0.03035622200894086   T=2,K=0:  33969 (0.063) ; 15609 (0.056) ; 7793 (0.044) ; nlsj96033 (0.041) ; 64316 (0.036) ; 22425 (0.034) ; 48436 (0.033) ; 106502 (0.030) ; 35417 (0.024) ; 84086 (0.024) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 45
# 0.2966260520051976   T=2,K=1:  73221 (0.103) ; 94677 (0.058) ; 13317 (0.055) ; 61245 (0.055) ; 114753 (0.048) ; 68335 (0.041) ; 75948 (0.032) ; 84295 (0.026) ; 110114 (0.025) ; 75954 (0.023) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 46
# 0.319450918739956   T=2,K=2:  28002 (0.067) ; 59501 (0.040) ; 22100 (0.037) ; 4536 (0.037) ; 113560 (0.035) ; 80761 (0.035) ; 86219 (0.035) ; 114816 (0.030) ; 31236 (0.029) ; 67009 (0.025) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 47
# 0.16728077155331927   T=2,K=3:  111764 (0.075) ; 57466 (0.061) ; 72268 (0.048) ; 112472 (0.047) ; 60646 (0.044) ; 46216 (0.039) ; 24436 (0.039) ; 15609 (0.038) ; 31236 (0.033) ; 94365 (0.031) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 48
# 0.18628603569258628   T=2,K=4:  110598 (0.068) ; 22209 (0.066) ; 51661 (0.049) ; nlsj80958 (0.047) ; 22100 (0.045) ; 35244 (0.030) ; 110639 (0.028) ; 31562 (0.027) ; 112833 (0.026) ; 56810 (0.026) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# 65
# 0.02115305572066461   T=3,K=0:  15609 (0.065) ; nlsj96033 (0.056) ; 7793 (0.047) ; 64316 (0.041) ; 33969 (0.040) ; 22425 (0.038) ; 35417 (0.034) ; 106502 (0.027) ; 71404 (0.024) ; 10933 (0.023) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 66
# 0.28901827347048026   T=3,K=1:  73221 (0.134) ; 13317 (0.079) ; 94677 (0.063) ; 61245 (0.043) ; 114753 (0.033) ; 75948 (0.027) ; 47735 (0.027) ; 71585 (0.026) ; 68335 (0.023) ; 75954 (0.023) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 67
# 0.20139874232845947   T=3,K=2:  28002 (0.076) ; 4536 (0.056) ; 59501 (0.048) ; 22100 (0.044) ; 80761 (0.036) ; 86219 (0.030) ; 67009 (0.028) ; 114816 (0.028) ; 113560 (0.027) ; 64316 (0.025) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 68
# 0.29355948177494157   T=3,K=3:  111764 (0.077) ; 24436 (0.065) ; 46216 (0.056) ; 112472 (0.047) ; 72268 (0.041) ; 60646 (0.039) ; 31236 (0.039) ; 57466 (0.039) ; 11072 (0.024) ; 15609 (0.024) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 69
# 0.1948704467054541   T=3,K=4:  22209 (0.084) ; 51661 (0.062) ; 110598 (0.059) ; nlsj80958 (0.049) ; 110639 (0.042) ; 22100 (0.041) ; 86108 (0.032) ; 35244 (0.028) ; 15609 (0.027) ; 56810 (0.025) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# 86
# 0.03203725161114594   T=4,K=0:  15609 (0.067) ; 7793 (0.049) ; nlsj96033 (0.043) ; 35417 (0.036) ; 48436 (0.035) ; 10933 (0.030) ; 64316 (0.029) ; 22425 (0.029) ; 106502 (0.027) ; 33969 (0.024) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 87
# 0.2218716902020156   T=4,K=1:  61245 (0.069) ; 94677 (0.067) ; 73221 (0.063) ; 13317 (0.062) ; 75948 (0.049) ; 75954 (0.030) ; 77030 (0.029) ; 71585 (0.028) ; 47735 (0.024) ; 114753 (0.022) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 88
# 0.15709769608973317   T=4,K=2:  28002 (0.122) ; 59501 (0.071) ; 22100 (0.040) ; 4536 (0.039) ; 67009 (0.035) ; 80761 (0.034) ; 93417 (0.030) ; 113560 (0.025) ; 96999 (0.024) ; 33969 (0.023) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 89
# 0.3100564406640618   T=4,K=3:  24436 (0.059) ; 111764 (0.057) ; 46216 (0.056) ; 57466 (0.043) ; 112472 (0.036) ; 60646 (0.034) ; 103957 (0.033) ; 11072 (0.031) ; 72268 (0.030) ; 15609 (0.030) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 90
# 0.27893692143304355   T=4,K=4:  51661 (0.071) ; 22209 (0.062) ; 110598 (0.059) ; 110639 (0.047) ; 86108 (0.044) ; nlsj80958 (0.039) ; 15609 (0.033) ; 22100 (0.032) ; 75954 (0.027) ; 56810 (0.026) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# 107
# 0.019523948015491278   T=5,K=0:  15609 (0.046) ; 7793 (0.046) ; 64316 (0.041) ; 35417 (0.040) ; nlsj96033 (0.039) ; 48436 (0.037) ; 106502 (0.032) ; 22425 (0.031) ; 84086 (0.029) ; 33969 (0.025) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 108
# 0.29205169614456516   T=5,K=1:  94677 (0.081) ; 73221 (0.054) ; 71585 (0.052) ; 13317 (0.041) ; 61245 (0.038) ; 75948 (0.037) ; 114753 (0.032) ; 75954 (0.031) ; 77030 (0.022) ; 47735 (0.021) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 109
# 0.05425359296632784   T=5,K=2:  28002 (0.130) ; 59501 (0.080) ; 80761 (0.039) ; 113560 (0.030) ; 93417 (0.028) ; 64316 (0.028) ; 67009 (0.027) ; 33969 (0.026) ; 108652 (0.025) ; 114816 (0.025) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 110
# 0.08372925851827727   T=5,K=3:  24436 (0.065) ; 72268 (0.050) ; 31236 (0.049) ; 111764 (0.049) ; 57466 (0.047) ; 103957 (0.039) ; 46216 (0.038) ; 34522 (0.033) ; 110639 (0.031) ; 94365 (0.030) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 111
# 0.5504415043553386   T=5,K=4:  110598 (0.093) ; 51661 (0.064) ; 110639 (0.049) ; 22209 (0.047) ; 15609 (0.042) ; nlsj80958 (0.032) ; 22100 (0.031) ; 56810 (0.028) ; 10056 (0.027) ; 86108 (0.027) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# 128
# 0.058248742046965576   T=6,K=0:  35417 (0.082) ; 7793 (0.054) ; 15609 (0.045) ; nlsj96033 (0.042) ; 22425 (0.030) ; 106502 (0.029) ; 33969 (0.028) ; nlsj42558 (0.026) ; 64316 (0.025) ; 84086 (0.023) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 129
# 0.16335271741637483   T=6,K=1:  73221 (0.066) ; 94677 (0.059) ; 75948 (0.055) ; 61245 (0.046) ; 71585 (0.043) ; 13317 (0.035) ; 75954 (0.032) ; 46216 (0.025) ; 67526 (0.025) ; 68335 (0.023) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 130
# 0.07389436343668285   T=6,K=2:  28002 (0.089) ; 59501 (0.082) ; 67009 (0.042) ; 80761 (0.041) ; 113560 (0.032) ; 114816 (0.031) ; 108652 (0.027) ; 96999 (0.026) ; 64316 (0.025) ; 46195 (0.025) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 131
# 0.07782261290885317   T=6,K=3:  24436 (0.074) ; 31236 (0.052) ; 103957 (0.052) ; 46216 (0.044) ; 72268 (0.043) ; 94365 (0.040) ; 57466 (0.037) ; 110639 (0.037) ; 75595 (0.036) ; 111764 (0.034) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# 132
# 0.6266815641911236   T=6,K=4:  110598 (0.081) ; 51661 (0.070) ; 110639 (0.050) ; 22209 (0.046) ; 22100 (0.041) ; 15609 (0.032) ; nlsj80958 (0.030) ; 17011 (0.029) ; 10056 (0.028) ; 56810 (0.028) ;
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_1' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_2' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/hengchen/git/seed-semantic-change/src/dynamic-senses/greek_input/all_results/genre_topic_output/unique_versions/example_3genre_output.dat_3' mode='w' encoding='UTF-8'>
